# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7662 non-null   object
#  1   Year             7662 non-null   int64
#  2   Value            7662 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 239.6+ KB

# %% [markdown]
# There are 4 columns and 4 rows in this dataset. The data types are floats, integers.

# %%
gdp_df.drop('Value Footnotes' ,axis =1)
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2021  1517.016266
# 1        Afghanistan  2020  1968.341002
# 2        Afghanistan  2019  2079.921861
# 3        Afghanistan  2018  2060.698973
# 4        Afghanistan  2017  2096.093111
# ...              ...   ...          ...
# 7657        Zimbabwe  1994  2670.106615
# 7658        Zimbabwe  1993  2458.783255
# 7659        Zimbabwe  1992  2468.278257
# 7660        Zimbabwe  1991  2781.787843
# 7661        Zimbabwe  1990  2704.757299
#
# [7662 rows x 3 columns]

# %%
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : ' GDP_Per_Capita'})
print(gd_rename)
# Out:
#           Country  Year   GDP_Per_Capita
# 0     Afghanistan  2021      1517.016266
# 1     Afghanistan  2020      1968.341002
# 2     Afghanistan  2019      2079.921861
# 3     Afghanistan  2018      2060.698973
# 4     Afghanistan  2017      2096.093111
# ...           ...   ...              ...
# 7657     Zimbabwe  1994      2670.106615
# 7658     Zimbabwe  1993      2458.783255
# 7659     Zimbabwe  1992      2468.278257
# 7660     Zimbabwe  1991      2781.787843
# 7661     Zimbabwe  1990      2704.757299
#
# [7662 rows x 3 columns]

# %%
print(gdp_df)
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2021  1517.016266
# 1        Afghanistan  2020  1968.341002
# 2        Afghanistan  2019  2079.921861
# 3        Afghanistan  2018  2060.698973
# 4        Afghanistan  2017  2096.093111
# ...              ...   ...          ...
# 7657        Zimbabwe  1994  2670.106615
# 7658        Zimbabwe  1993  2458.783255
# 7659        Zimbabwe  1992  2468.278257
# 7660        Zimbabwe  1991  2781.787843
# 7661        Zimbabwe  1990  2704.757299
#
# [7662 rows x 3 columns]

# %%
print(any(gdp_df.Value ==0 ))
# Out:
# False

# %%
missing_values = gdp_df.isnull()
print(missing_values)
# Out:
#       Country or Area   Year  Value
# 0               False  False  False
# 1               False  False  False
# 2               False  False  False
# 3               False  False  False
# 4               False  False  False
# ...               ...    ...    ...
# 7657            False  False  False
# 7658            False  False  False
# 7659            False  False  False
# 7660            False  False  False
# 7661            False  False  False
#
# [7662 rows x 3 columns]

# %% [markdown]
# I do not see any countries missing data in this dataset based on the two calculations made above.

# %%
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : ' GDP_Per_Capita'})
gdp_2020 = gd_rename[gd_rename["Year"] == 2020]
print(gdp_2020)
# Out:
#                           Country  Year   GDP_Per_Capita
# 1                     Afghanistan  2020      1968.341002
# 22    Africa Eastern and Southern  2020      3455.023119
# 55     Africa Western and Central  2020      3957.933804
# 88                        Albania  2020     13278.369769
# 121                       Algeria  2020     10844.770764
# ...                           ...   ...              ...
# 7503                     Viet Nam  2020     10450.622382
# 7536           West Bank and Gaza  2020      5402.538773
# 7565                        World  2020     16204.169107
# 7598                       Zambia  2020      3183.650773
# 7631                     Zimbabwe  2020      1990.319419
#
# [242 rows x 3 columns]

# %%
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : ' GDP_Per_Capita'})
gdp_2020 = gd_rename[gd_rename["Year"] == 2020]
plt.hist(gdp_2020)
plt.xlabel('GDP_Per_Capita')
plt.ylabel('Year')
plt.show()

# %% [markdown]
#  ^^ Histogram of GDP_Per_Capita in 2020 for all countries ^^

# %%
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
gdp_2020 = gd_rename[gd_rename["Year"] == 2020]
sns.kdeplot(gdp_2020['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='Density'>

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
gdp_2020 = gd_rename[gd_rename["Year"] == 2020]
sns.boxplot(x=gdp_2020['Year'], y=gdp_2020['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : "GDP_Per_Capita"})
gdp_2020 = gd_rename[gd_rename["Year"] == 2020]
sns.violinplot(x=gdp_2020["Year"], y=gdp_2020["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : "GDP_Per_Capita"})
gdp_2020 = gd_rename[gd_rename["Year"] == 2020]
print(gdp_2020["GDP_Per_Capita"].median())
# Out:
# 13357.997573370474

# %% [markdown]
# --- Median GDP Per Capita ion the Year 2020 == 13357.997573370474

# %%
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : ' GDP_Per_Capita'})
gdp_decades = gd_rename[(gd_rename["Year"] == 1990) | (gd_rename["Year"] == 2000) | (gd_rename["Year"] == 2010) | (gd_rename["Year"] == 2020)]
gdp_decades_sorted = gdp_decades.sort_values("Year", ascending=False)
print(gdp_decades_sorted)
# Out:
#                          Country  Year   GDP_Per_Capita
# 1                    Afghanistan  2020      1968.341002
# 1696                    Djibouti  2020      4753.887886
# 1772  Early-demographic dividend  2020      8929.724924
# 5449            Papua New Guinea  2020      3741.661578
# 3571                       Korea  2020     42396.761944
# ...                          ...   ...              ...
# 2589                      Greece  1990     24262.842581
# 2556                       Ghana  1990      2299.638794
# 6072                  Seychelles  1990     15538.802834
# 2523                     Germany  1990     36699.481703
# 7661                    Zimbabwe  1990      2704.757299
#
# [921 rows x 3 columns]

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
gdp_decades = gd_rename[(gd_rename["Year"] == 1990) | (gd_rename["Year"] == 2000) | (gd_rename["Year"] == 2010) | (gd_rename["Year"] == 2020)]
gdp_decades_sorted = gdp_decades.sort_values("Year", ascending=False)
plt.title('GDP Values Per Decade',
          fontsize = 14,
          fontweight = 'bold')
sns.boxplot(x=gdp_decades_sorted['Year'], y=gdp_decades_sorted['GDP_Per_Capita'])
# Out:
# <Axes: title={'center': 'GDP Values Per Decade'}, xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
gdp_decades = gd_rename[(gd_rename["Year"] == 1990) | (gd_rename["Year"] == 2000) | (gd_rename["Year"] == 2010) | (gd_rename["Year"] == 2020)]
gdp_decades_sorted = gdp_decades.sort_values("Year", ascending=False)

groupedvalues = gdp_decades.groupby('Year').sum().reset_index()
g = sns.barplot(x='Year',y='GDP_Per_Capita', data =groupedvalues)

plt.xticks(rotation =0, fontsize = 12)
plt.title('GDP Values Per Decade',
          fontsize = 14,
          fontweight = 'bold');

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
gdp_decades = gd_rename[(gd_rename["Year"] == 1990) | (gd_rename["Year"] == 2000) | (gd_rename["Year"] == 2010) | (gd_rename["Year"] == 2020)]
gdp_decades_sorted = gdp_decades.sort_values("Year", ascending=False)
sns.regplot(x=gdp_decades_sorted["Year"],y=gdp_decades_sorted["GDP_Per_Capita"], line_kws={"color":"r"})
plt.title('GDP Values Per Decade',
          fontsize = 14,
          fontweight = 'bold')
plt.show()

# %%
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
first_value = gd_rename.loc[gd_rename['GDP_Per_Capita'] > 100000].iloc[0]
print(first_value)
# Out:
# Country                Ireland
# Year                      2022
# GDP_Per_Capita    113870.78555
# Name: 3277, dtype: object

# %% [markdown]
# Which country was the first to have a GDP per capita greater than $100,000? Ireland

# %%
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
year_twoo = gd_rename.loc[gd_rename['Year'] == 2020]
sorted_df = year_twoo.sort_values(by=['GDP_Per_Capita'], ascending=False)
print(sorted_df)
# Out:
#                        Country  Year  GDP_Per_Capita
# 4148                Luxembourg  2020   111751.314751
# 6108                 Singapore  2020    94910.101431
# 3279                   Ireland  2020    91356.855054
# 5746                     Qatar  2020    89019.069857
# 681                    Bermuda  2020    76117.804744
# ...                        ...   ...             ...
# 5074                     Niger  2020     1214.546556
# 6273                   Somalia  2020     1127.418534
# 1630           Dem. Rep. Congo  2020     1044.071214
# 1217  Central African Republic  2020      847.765012
# 973                    Burundi  2020      711.355263
#
# [242 rows x 3 columns]

# %% [markdown]
# Which country had the highest GDP per capita in 2020? Luxembourg

# %%
---12.
import seaborn as sns
import pandas as pd
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
filtered_df = gd_rename[gd_rename['Country'] == 'Luxembourg']
sns.regplot(x=filtered_df['Year'], y=filtered_df['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# ^^ Create a plot showing how this Luxembourg's GDP per capita has changed over the timespan of the dataset. ^^

# %%
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
year_twoo = gd_rename.loc[gd_rename['Year'] == 2020]
sorted_df = year_twoo.sort_values(by=['GDP_Per_Capita'], ascending=True)
print(sorted_df)
# Out:
#                        Country  Year  GDP_Per_Capita
# 973                    Burundi  2020      711.355263
# 1217  Central African Republic  2020      847.765012
# 1630           Dem. Rep. Congo  2020     1044.071214
# 6273                   Somalia  2020     1127.418534
# 5074                     Niger  2020     1214.546556
# ...                        ...   ...             ...
# 681                    Bermuda  2020    76117.804744
# 5746                     Qatar  2020    89019.069857
# 3279                   Ireland  2020    91356.855054
# 6108                 Singapore  2020    94910.101431
# 4148                Luxembourg  2020   111751.314751
#
# [242 rows x 3 columns]

# %%
Which country had the lowest GDP per capita in 2020? Burundi

# %%
import seaborn as sns
import pandas as pd
gdp_df = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\gdp_percapita1.csv")
gd = gdp_df.drop('Value Footnotes' ,axis =1)
gd_rename = gd.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'GDP_Per_Capita'})
filtered_df = gd_rename[gd_rename['Country'] == 'Burundi']
sns.regplot(x=filtered_df['Year'], y=filtered_df['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# ^^^ Create a plot showing how Burundi's GDP per capita has changed over the timespan of the dataset. ^^^

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
internet_use = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\internet_use_1.csv", nrows = 6083)

# %%
print(internet_use)
# Out:
#      Country or Area  Year      Value Value Footnotes
# 0        Afghanistan  2019  17.600000               1
# 1        Afghanistan  2018  16.800000               2
# 2        Afghanistan  2017  13.500000               3
# 3        Afghanistan  2016  11.000000               4
# 4        Afghanistan  2015   8.260000               4
# ...              ...   ...        ...             ...
# 6078        Zimbabwe  1997   0.033080             NaN
# 6079        Zimbabwe  1996   0.016790             NaN
# 6080        Zimbabwe  1995   0.007684             NaN
# 6081        Zimbabwe  1994   0.001739             NaN
# 6082        Zimbabwe  1990   0.000000             NaN
#
# [6083 rows x 4 columns]

# %%
internet_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6083 non-null   object
#  1   Year             6083 non-null   int64
#  2   Value            6083 non-null   float64
#  3   Value Footnotes  2826 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 190.2+ KB

# %%
iu = internet_use.drop('Value Footnotes' ,axis =1)
iu_rename = iu.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : ' Internet_Users_Pct'})
print(iu_rename)
# Out:
#           Country  Year   Internet_Users_Pct
# 0     Afghanistan  2019            17.600000
# 1     Afghanistan  2018            16.800000
# 2     Afghanistan  2017            13.500000
# 3     Afghanistan  2016            11.000000
# 4     Afghanistan  2015             8.260000
# ...           ...   ...                  ...
# 6078     Zimbabwe  1997             0.033080
# 6079     Zimbabwe  1996             0.016790
# 6080     Zimbabwe  1995             0.007684
# 6081     Zimbabwe  1994             0.001739
# 6082     Zimbabwe  1990             0.000000
#
# [6083 rows x 3 columns]

# %% [markdown]
# Looking at the information in this dataset I can tell that the number of observations is less than the number in the previous, GDP_Per_Capita dataset. I also notice that it seems that this datset is already sorted somewhat in a descending order by the percentage of internet users.

# %%
internet_use = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\internet_use_1.csv", nrows = 6083)
iu = internet_use.drop('Value Footnotes' ,axis =1)
iu_rename = iu.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'Internet_Users_Pct'})
first_year = iu_rename.loc[iu_rename['Internet_Users_Pct'] != 0].iloc[0]
print(first_year)
# Out:
# Country               Afghanistan
# Year                         2019
# Internet_Users_Pct           17.6
# Name: 0, dtype: object

# %%
Afghanistan was the first year to have a non-zero internet users percentage value.

# %%
internet_use = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\internet_use_1.csv", nrows = 6083)
iu = internet_use.drop('Value Footnotes' ,axis =1)
iu_rename = iu.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'Internet_Users_Pct'})
filtered_df = iu_rename[iu_rename['Year'] == 2000]
sorted_df = filtered_df.sort_values(by=['Internet_Users_Pct'], ascending=False)
print(sorted_df)
# Out:
#                                     Country  Year  Internet_Users_Pct
# 1907            Falkland (Malvinas) Islands  2000           58.620700
# 4187                                 Norway  2000           52.000000
# 1000                                 Canada  2000           51.300000
# 4757                             San Marino  2000           48.799500
# 4026                            New Zealand  2000           47.379600
# ...                                     ...   ...                 ...
# 5068                                Somalia  2000            0.020000
# 3247                                Liberia  2000            0.017703
# 1884                               Ethiopia  2000            0.015264
# 1531       Democratic Republic of the Congo  2000            0.005902
# 1504  Democratic People's Republic of Korea  2000            0.000000
#
# [210 rows x 3 columns]

# %%
internet_use = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\internet_use_1.csv", nrows = 6083)
iu = internet_use.drop('Value Footnotes' ,axis =1)
iu_rename = iu.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'Internet_Users_Pct'})
filtered_df = iu_rename[iu_rename['Year'] == 2014]
sorted_df = filtered_df.sort_values(by=['Internet_Users_Pct'], ascending=False)
print(sorted_df)
# Out:
#                           Country  Year  Internet_Users_Pct
# 2592                      Iceland  2014            98.15800
# 1893  Falkland (Malvinas) Islands  2014            97.60000
# 602                       Bermuda  2014            96.80000
# 4173                       Norway  2014            96.30050
# 1546                      Denmark  2014            95.99350
# ...                           ...   ...                 ...
# 5116                  South Sudan  2014             2.60000
# 5055                      Somalia  2014             1.63000
# 4073                        Niger  2014             1.24868
# 873                       Burundi  2014             1.04239
# 1782                      Eritrea  2014             0.99000
#
# [204 rows x 3 columns]

# %% [markdown]
# It seems that there is more data displaying internet users in the year 2000 than the year 2014.However, it seems that in the year 2014 the have higher percentages in terms of users with their highest percentage showing 98 and the highest internet usage in 2000 would be 58.

# %%
internet_use = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\internet_use_1.csv", nrows = 6083)
iu = internet_use.drop('Value Footnotes' ,axis =1)
iu_rename = iu.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'Internet_Users_Pct'})
filtered_df_combo = iu_rename[(iu_rename['Year'] == 2000)  | (iu_rename['Year'] == 2014)]
print(filtered_df_combo.shape)
print(filtered_df_combo)
# Out:
# (414, 3)
#           Country  Year  Internet_Users_Pct
# 5     Afghanistan  2014            7.000000
# 28        Albania  2014           54.300000
# 42        Albania  2000            0.114097
# 57        Algeria  2014           29.500000
# 71        Algeria  2000            0.491706
# ...           ...   ...                 ...
# 6017        Yemen  2000            0.082500
# 6031       Zambia  2014            6.500000
# 6045       Zambia  2000            0.191072
# 6061     Zimbabwe  2014           16.364700
# 6075     Zimbabwe  2000            0.401434
#
# [414 rows x 3 columns]

# %%
internet_use = pd.read_csv(r"C:\DA12\Projects\Python\Projects\un-python-wileymartin\data\internet_use_1.csv", nrows = 6083)
iu = internet_use.drop('Value Footnotes',axis =1 )
iu_rename = iu.rename(columns={'Country or Area' : 'Country', 'Year' : 'Year' , 'Value' : 'Internet_Users_Pct'})
filtered_df_combo = iu_rename[iu_rename['Year'] == 2014]
criteria_df = filtered_df_combo[filtered_df.iloc[:,2] <= 5.0 ]
print(criteria_df)
# Out:
#                                Country  Year  Internet_Users_Pct
# 873                            Burundi  2014             1.04239
# 1033          Central African Republic  2014             2.70000
# 1061                              Chad  2014             2.90000
# 1517  Democratic Republic of the Congo  2014             3.00000
# 1782                           Eritrea  2014             0.99000
# 2451                     Guinea-Bissau  2014             3.32000
# 3364                        Madagascar  2014             3.70000
# 4073                             Niger  2014             1.24868
# 5055                           Somalia  2014             1.63000
# 5116                       South Sudan  2014             2.60000

# %% [markdown]
# It seems that for ten countries the percentage of internet users was below 5 %.

# %%
frames = [criteria_df, filtered_df_combo]
result=  pd.concat(frames)
print(result)
# Out:
#                                Country  Year  Internet_Users_Pct
# 873                            Burundi  2014            1.042390
# 1033          Central African Republic  2014            2.700000
# 1061                              Chad  2014            2.900000
# 1517  Democratic Republic of the Congo  2014            3.000000
# 1782                           Eritrea  2014            0.990000
# ...                                ...   ...                 ...
# 6017                             Yemen  2000            0.082500
# 6031                            Zambia  2014            6.500000
# 6045                            Zambia  2000            0.191072
# 6061                          Zimbabwe  2014           16.364700
# 6075                          Zimbabwe  2000            0.401434
#
# [424 rows x 3 columns]

# %%
frames = [iu_rename, gd_rename]
gdp_and_internet_use = pd.concat(frames)
print(gdp_and_internet_use)
# Out:
#           Country  Year  Internet_Users_Pct   GDP_Per_Capita
# 0     Afghanistan  2019               17.60              NaN
# 1     Afghanistan  2018               16.80              NaN
# 2     Afghanistan  2017               13.50              NaN
# 3     Afghanistan  2016               11.00              NaN
# 4     Afghanistan  2015                8.26              NaN
# ...           ...   ...                 ...              ...
# 7657     Zimbabwe  1994                 NaN      2670.106615
# 7658     Zimbabwe  1993                 NaN      2458.783255
# 7659     Zimbabwe  1992                 NaN      2468.278257
# 7660     Zimbabwe  1991                 NaN      2781.787843
# 7661     Zimbabwe  1990                 NaN      2704.757299
#
# [13745 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

frames = [criteria_df, filtered_df_combo]
result=  pd.concat(frames)

groupedvalues = result.groupby('Country').sum().reset_index()
g = sns.barplot(x='Country',y='Internet_Users_Pct', data =groupedvalues)

# %%
frames = [iu_rename, gd_rename]
gdp_and_internet_use = pd.concat(frames)
gdp_and_internet_use.loc[gdp_and_internet_use['Year'] == 2014]
gdp_and_internet_use.dropna()
gdp_and_internet_use_2014= print(gdp_and_internet_use[gdp_and_internet_use['Year'] == 2014])
# Out:
#                  Country  Year  Internet_Users_Pct   GDP_Per_Capita
# 5            Afghanistan  2014              7.0000              NaN
# 28               Albania  2014             54.3000              NaN
# 57               Algeria  2014             29.5000              NaN
# 87               Andorra  2014             86.1000              NaN
# 114               Angola  2014             21.3623              NaN
# ...                  ...   ...                 ...              ...
# 7509            Viet Nam  2014                 NaN      7641.909252
# 7542  West Bank and Gaza  2014                 NaN      5967.073437
# 7571               World  2014                 NaN     15120.730322
# 7604              Zambia  2014                 NaN      3375.941270
# 7637            Zimbabwe  2014                 NaN      2316.954536
#
# [446 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
frames = [iu_rename, gd_rename]
gdp_and_internet_use = pd.concat(frames)
gdp_and_internet_use.loc[gdp_and_internet_use['Year'] == 2014]
gdp_and_internet_use_2014= print(gdp_and_internet_use[gdp_and_internet_use['Year'] == 2014])

sns.scatterplot(x=gdp_and_internet_use_2014['GDP_Per_Capita'], y=gdp_and_internet_use_2014['Internet_Users_Pct'])
# Out:
#                  Country  Year  Internet_Users_Pct   GDP_Per_Capita
# 5            Afghanistan  2014              7.0000              NaN
# 28               Albania  2014             54.3000              NaN
# 57               Algeria  2014             29.5000              NaN
# 87               Andorra  2014             86.1000              NaN
# 114               Angola  2014             21.3623              NaN
# ...                  ...   ...                 ...              ...
# 7509            Viet Nam  2014                 NaN      7641.909252
# 7542  West Bank and Gaza  2014                 NaN      5967.073437
# 7571               World  2014                 NaN     15120.730322
# 7604              Zambia  2014                 NaN      3375.941270
# 7637            Zimbabwe  2014                 NaN      2316.954536
#
# [446 rows x 4 columns]
# ---------------------------------------------------------------------------
# ...
